# %% [markdown]
# # Compare the wavenumber spectra of ROMS surface SST and heatflux quantities

# %%
import dask
dask.config.set(scheduler='processes')

# %%
import xarray as xr
import numpy as np

from matplotlib import rcParams
from scipy.interpolate import interp1d

rcParams["font.size"] = "14"
rcParams['axes.labelsize']='medium'

import matplotlib.pyplot as plt

from sfoda.utils.barycentric import BarycentricInterp
# Out:
# Bad key "backend.qt5" on line 5 in
# /home/mrayson/.config/matplotlib/matplotlibrc.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# %matplotlib notebook

# %%
# roms4dvarfiles = '../ROMSdata/4DVAR_OUT/archive_qck_6*.nc'
#romsverfiles = '../ROMSdata/4DVAR_OUT/archive_qck_ver_63[0-3]*.nc'

romsverfiles = ['../ROMSdata/4DVAR_OUT/archive_qck_ver_6301.nc']
roms4dvarfiles = ['../ROMSdata/4DVAR_OUT/archive_qck_6301.nc']

romsverfiles = ['../ROMSdata/4DVAR_OUT/archive_qck_ver_6333.nc']
roms4dvarfiles = ['../ROMSdata/4DVAR_OUT/archive_qck_6333.nc']

#romsfile = '../DATA/ROMS_NWS_2km_2017_2019_u_Harmonics.nc'

ds = xr.open_mfdataset(romsverfiles)
nt = ds.dims['ocean_time']
ds
# Out:
# <xarray.Dataset>
# Dimensions:          (boundary: 4, eta_psi: 481, eta_rho: 482, eta_u: 482, eta_v: 481, ocean_time: 97, s_rho: 30, s_w: 31, tracer: 2, xi_psi: 1009, xi_rho: 1010, xi_u: 1009, xi_v: 1010)
# Coordinates:
#     lat_psi          (eta_psi, xi_psi) float64 dask.array<chunksize=(481, 1009), meta=np.ndarray>
#     lat_rho          (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     lat_u            (eta_u, xi_u) float64 dask.array<chunksize=(482, 1009), meta=np.ndarray>
#     lat_v            (eta_v, xi_v) float64 dask.array<chunksize=(481, 1010), meta=np.ndarray>
#     lon_psi          (eta_psi, xi_psi) float64 dask.array<chunksize=(481, 1009), meta=np.ndarray>
#     lon_rho          (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     lon_u            (eta_u, xi_u) float64 dask.array<chunksize=(482, 1009), meta=np.ndarray>
#     lon_v            (eta_v, xi_v) float64 dask.array<chunksize=(481, 1010), meta=np.ndarray>
#   * ocean_time       (ocean_time) datetime64[ns] 2017-05-04 ... 2017-05-08
#   * s_rho            (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w              (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.03333 0.0
# Dimensions without coordinates: boundary, eta_psi, eta_rho, eta_u, eta_v, tracer, xi_psi, xi_rho, xi_u, xi_v
# Data variables:
#     Akk_bak          float64 ...
#     Akp_bak          float64 ...
#     Akt_bak          (tracer) float64 dask.array<chunksize=(2,), meta=np.ndarray>
#     Akv_bak          float64 ...
#     Cs_r             (s_rho) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     Cs_w             (s_w) float64 dask.array<chunksize=(31,), meta=np.ndarray>
#     FSobc_in         (boundary) float64 dask.array<chunksize=(4,), meta=np.ndarray>
#     FSobc_out        (boundary) float64 dask.array<chunksize=(4,), meta=np.ndarray>
#     Falpha           float64 ...
#     Fbeta            float64 ...
#     Fgamma           float64 ...
#     Lm2CLM           int32 ...
#     Lm3CLM           int32 ...
#     LnudgeM2CLM      int32 ...
#     LnudgeM3CLM      int32 ...
#     LnudgeTCLM       (tracer) int32 dask.array<chunksize=(2,), meta=np.ndarray>
#     LsshCLM          int32 ...
#     LtracerCLM       (tracer) int32 dask.array<chunksize=(2,), meta=np.ndarray>
#     LtracerSponge    (tracer) int32 dask.array<chunksize=(2,), meta=np.ndarray>
#     LtracerSrc       (tracer) int32 dask.array<chunksize=(2,), meta=np.ndarray>
#     LuvSponge        int32 ...
#     LuvSrc           int32 ...
#     LwSrc            int32 ...
#     M2nudg           float64 ...
#     M2obc_in         (boundary) float64 dask.array<chunksize=(4,), meta=np.ndarray>
#     M2obc_out        (boundary) float64 dask.array<chunksize=(4,), meta=np.ndarray>
#     M3nudg           float64 ...
#     M3obc_in         (boundary) float64 dask.array<chunksize=(4,), meta=np.ndarray>
#     M3obc_out        (boundary) float64 dask.array<chunksize=(4,), meta=np.ndarray>
#     Tcline           float64 ...
#     Tnudg            (tracer) float64 dask.array<chunksize=(2,), meta=np.ndarray>
#     Tobc_in          (boundary, tracer) float64 dask.array<chunksize=(4, 2), meta=np.ndarray>
#     Tobc_out         (boundary, tracer) float64 dask.array<chunksize=(4, 2), meta=np.ndarray>
#     Vstretching      int32 ...
#     Vtransform       int32 ...
#     Znudg            float64 ...
#     Zob              float64 ...
#     Zos              float64 ...
#     angle            (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     dstart           datetime64[ns] ...
#     dt               float64 ...
#     dtfast           float64 ...
#     el               float64 ...
#     f                (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     gamma2           float64 ...
#     grid             int32 ...
#     h                (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     hc               float64 ...
#     mask_psi         (eta_psi, xi_psi) float64 dask.array<chunksize=(481, 1009), meta=np.ndarray>
#     mask_rho         (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     mask_u           (eta_u, xi_u) float64 dask.array<chunksize=(482, 1009), meta=np.ndarray>
#     mask_v           (eta_v, xi_v) float64 dask.array<chunksize=(481, 1010), meta=np.ndarray>
#     nAVG             int32 ...
#     nHIS             int32 ...
#     nRST             int32 ...
#     nSTA             int32 ...
#     ndefAVG          int32 ...
#     ndefHIS          int32 ...
#     ndtfast          int32 ...
#     nl_tnu2          (tracer) float64 dask.array<chunksize=(2,), meta=np.ndarray>
#     nl_visc2         float64 ...
#     ntimes           int32 ...
#     ntsAVG           int32 ...
#     pm               (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     pn               (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     rdrg             float64 ...
#     rdrg2            float64 ...
#     rho0             float64 ...
#     salt_sur         (ocean_time, eta_rho, xi_rho) float32 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     shflux           (ocean_time, eta_rho, xi_rho) float32 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     spherical        int32 ...
#     ssflux           (ocean_time, eta_rho, xi_rho) float32 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     sustr            (ocean_time, eta_u, xi_u) float32 dask.array<chunksize=(97, 482, 1009), meta=np.ndarray>
#     svstr            (ocean_time, eta_v, xi_v) float32 dask.array<chunksize=(97, 481, 1010), meta=np.ndarray>
#     temp_sur         (ocean_time, eta_rho, xi_rho) float32 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     theta_b          float64 ...
#     theta_s          float64 ...
#     u_sur_eastward   (ocean_time, eta_rho, xi_rho) float32 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     ubar_eastward    (ocean_time, eta_rho, xi_rho) float32 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     v_sur_northward  (ocean_time, eta_rho, xi_rho) float32 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     vbar_northward   (ocean_time, eta_rho, xi_rho) float32 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     xl               float64 ...
#     zeta             (ocean_time, eta_rho, xi_rho) float32 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
# Attributes:
#     file:              ./outputs/qck.nc
#     format:            netCDF-3 64bit offset file
#     Conventions:       CF-1.4, SGRID-0.3
#     type:              ROMS/TOMS quicksave file
#     title:             NWS VERIFICATION ROMS
#     var_info:          varinfo.dat
#     rst_file:          ./outputs/rst.nc
#     avg_file:          ./outputs/avg.nc
#     sta_file:          ./outputs/sta.nc
#     grd_file:          grid.nc
#     ini_file:          ini.nc
#     tide_file:         tide.nc
#     frc_file_01:       forcing.nc
#     clm_file_01:       bry.nc
#     script_file:       ocean.in
#     spos_file:         stations.in
#     NLM_TADV:          \nADVECTION:   HORIZONTAL   VERTICAL     \ntemp:      ...
#     NLM_LBC:           \nEDGE:  WEST   SOUTH  EAST   NORTH  \nzeta:  Cha    C...
#     svn_url:           https://www.myroms.org/svn/src/trunk
#     svn_rev:           1037
#     code_dir:          /group/pawsey0219/ijanekovic/GIT/testing/trunk
#     header_dir:        /group/pawsey0219/ijanekovic/NWS_ASSIM
#     header_file:       nws_verification.h
#     os:                Linux
#     cpu:               x86_64
#     compiler_system:   ftn
#     compiler_command:  /opt/cray/pe/craype/2.5.13/bin/ftn
#     compiler_flags:    -fp-model precise -heap-arrays -ip -O3
#     tiling:            024x010
#     history:           Sat Sep 26 18:14:38 2020: ncks -7 --ppc default=.5 -O ...
#     ana_file:          ROMS/Functionals/ana_btflux.h
#     CPP_options:       NWS_VERIFICATION, ADD_FSOBC, ADD_M2OBC, ANA_BSFLUX, AN...
#     NCO:               netCDF Operators version 4.7.6 (Homepage = http://nco....

# %%
ds.ocean_time[0].values,ds.ocean_time[-1].values
# Out:
# (numpy.datetime64('2017-05-04T00:00:00.000000000'),
#  numpy.datetime64('2017-05-08T00:00:00.000000000'))

# %%
# Load the 4Dvar and clip the overlapping time dimensions
ds4d = xr.open_mfdataset(roms4dvarfiles)
ds4d = ds4d.isel(ocean_time=range(0,nt))
ds4d
# Out:
# <xarray.Dataset>
# Dimensions:          (Nstate: 11, boundary: 4, eta_psi: 481, eta_rho: 482, eta_u: 482, eta_v: 481, ocean_time: 97, s_rho: 30, s_w: 31, tracer: 2, xi_psi: 1009, xi_rho: 1010, xi_u: 1009, xi_v: 1010)
# Coordinates:
#     lat_psi          (eta_psi, xi_psi) float64 dask.array<chunksize=(481, 1009), meta=np.ndarray>
#     lat_rho          (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     lat_u            (eta_u, xi_u) float64 dask.array<chunksize=(482, 1009), meta=np.ndarray>
#     lat_v            (eta_v, xi_v) float64 dask.array<chunksize=(481, 1010), meta=np.ndarray>
#     lon_psi          (eta_psi, xi_psi) float64 dask.array<chunksize=(481, 1009), meta=np.ndarray>
#     lon_rho          (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     lon_u            (eta_u, xi_u) float64 dask.array<chunksize=(482, 1009), meta=np.ndarray>
#     lon_v            (eta_v, xi_v) float64 dask.array<chunksize=(481, 1010), meta=np.ndarray>
#   * ocean_time       (ocean_time) datetime64[ns] 2017-05-04 ... 2017-05-08
#   * s_rho            (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w              (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.03333 0.0
# Dimensions without coordinates: Nstate, boundary, eta_psi, eta_rho, eta_u, eta_v, tracer, xi_psi, xi_rho, xi_u, xi_v
# Data variables:
#     Akk_bak          float64 ...
#     Akp_bak          float64 ...
#     Akt_bak          (tracer) float64 dask.array<chunksize=(2,), meta=np.ndarray>
#     Akv_bak          float64 ...
#     Cs_r             (s_rho) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     Cs_w             (s_w) float64 dask.array<chunksize=(31,), meta=np.ndarray>
#     Falpha           float64 ...
#     Fbeta            float64 ...
#     Fgamma           float64 ...
#     GradErr          float64 ...
#     Hdecay           (Nstate) float64 dask.array<chunksize=(11,), meta=np.ndarray>
#     HdecayB          (boundary, Nstate) float64 dask.array<chunksize=(4, 11), meta=np.ndarray>
#     HdecayM          (Nstate) float64 dask.array<chunksize=(11,), meta=np.ndarray>
#     HevecErr         float64 ...
#     Hgamma           float64 ...
#     HgammaB          float64 ...
#     HgammaF          float64 ...
#     HgammaM          float64 ...
#     LhessianEV       int32 ...
#     LhotStart        int32 ...
#     Lm2CLM           int32 ...
#     Lm3CLM           int32 ...
#     LnudgeM2CLM      int32 ...
#     LnudgeM3CLM      int32 ...
#     LnudgeTCLM       (tracer) int32 dask.array<chunksize=(2,), meta=np.ndarray>
#     Lobc             (Nstate, boundary) int32 dask.array<chunksize=(11, 4), meta=np.ndarray>
#     Lprecond         int32 ...
#     Lritz            int32 ...
#     LsshCLM          int32 ...
#     Lstflux          (tracer) int32 dask.array<chunksize=(2,), meta=np.ndarray>
#     LtracerCLM       (tracer) int32 dask.array<chunksize=(2,), meta=np.ndarray>
#     LtracerSponge    (tracer) int32 dask.array<chunksize=(2,), meta=np.ndarray>
#     LtracerSrc       (tracer) int32 dask.array<chunksize=(2,), meta=np.ndarray>
#     LuvSponge        int32 ...
#     LuvSrc           int32 ...
#     LwSrc            int32 ...
#     M2nudg           float64 ...
#     M3nudg           float64 ...
#     Ninner           int32 ...
#     Nmethod          int32 ...
#     Nouter           int32 ...
#     Nrandom          int32 ...
#     R0               float64 ...
#     Rscheme          int32 ...
#     Scoef            float64 ...
#     Tcline           float64 ...
#     Tcoef            float64 ...
#     Tnudg            (tracer) float64 dask.array<chunksize=(2,), meta=np.ndarray>
#     Vdecay           (Nstate) float64 dask.array<chunksize=(11,), meta=np.ndarray>
#     VdecayB          (boundary, Nstate) float64 dask.array<chunksize=(4, 11), meta=np.ndarray>
#     VdecayM          (Nstate) float64 dask.array<chunksize=(11,), meta=np.ndarray>
#     Vgamma           float64 ...
#     VgammaB          float64 ...
#     VgammaM          float64 ...
#     Vstretching      int32 ...
#     Vtransform       int32 ...
#     Znudg            float64 ...
#     Zob              float64 ...
#     Zos              float64 ...
#     ad_Akt_fac       (tracer) float64 dask.array<chunksize=(2,), meta=np.ndarray>
#     ad_Akv_fac       float64 ...
#     ad_tnu2          (tracer) float64 dask.array<chunksize=(2,), meta=np.ndarray>
#     ad_visc2         float64 ...
#     angle            (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     dstart           datetime64[ns] ...
#     dt               float64 ...
#     dtfast           float64 ...
#     el               float64 ...
#     f                (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     gamma2           float64 ...
#     grid             int32 ...
#     h                (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     hc               float64 ...
#     mask_psi         (eta_psi, xi_psi) float64 dask.array<chunksize=(481, 1009), meta=np.ndarray>
#     mask_rho         (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     mask_u           (eta_u, xi_u) float64 dask.array<chunksize=(482, 1009), meta=np.ndarray>
#     mask_v           (eta_v, xi_v) float64 dask.array<chunksize=(481, 1010), meta=np.ndarray>
#     nADJ             int32 ...
#     nAVG             int32 ...
#     nHIS             int32 ...
#     nOBC             int32 ...
#     nRST             int32 ...
#     nSFF             int32 ...
#     nSTA             int32 ...
#     nTLM             int32 ...
#     ndefADJ          int32 ...
#     ndefAVG          int32 ...
#     ndefHIS          int32 ...
#     ndefTLM          int32 ...
#     ndtfast          int32 ...
#     nl_tnu2          (tracer) float64 dask.array<chunksize=(2,), meta=np.ndarray>
#     nl_visc2         float64 ...
#     ntimes           int32 ...
#     ntsAVG           int32 ...
#     pm               (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     pn               (eta_rho, xi_rho) float64 dask.array<chunksize=(482, 1010), meta=np.ndarray>
#     rdrg             float64 ...
#     rdrg2            float64 ...
#     rho0             float64 ...
#     salt_sur         (ocean_time, eta_rho, xi_rho) float64 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     shflux           (ocean_time, eta_rho, xi_rho) float64 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     spherical        int32 ...
#     ssflux           (ocean_time, eta_rho, xi_rho) float64 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     sustr            (ocean_time, eta_u, xi_u) float64 dask.array<chunksize=(97, 482, 1009), meta=np.ndarray>
#     svstr            (ocean_time, eta_v, xi_v) float64 dask.array<chunksize=(97, 481, 1010), meta=np.ndarray>
#     temp_sur         (ocean_time, eta_rho, xi_rho) float64 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     theta_b          float64 ...
#     theta_s          float64 ...
#     tl_Akt_fac       (tracer) float64 dask.array<chunksize=(2,), meta=np.ndarray>
#     tl_Akv_fac       float64 ...
#     tl_tnu2          (tracer) float64 dask.array<chunksize=(2,), meta=np.ndarray>
#     tl_visc2         float64 ...
#     u_sur_eastward   (ocean_time, eta_rho, xi_rho) float64 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     ubar_eastward    (ocean_time, eta_rho, xi_rho) float64 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     v_sur_northward  (ocean_time, eta_rho, xi_rho) float64 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     vbar_northward   (ocean_time, eta_rho, xi_rho) float64 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
#     xl               float64 ...
#     zeta             (ocean_time, eta_rho, xi_rho) float64 dask.array<chunksize=(97, 482, 1010), meta=np.ndarray>
# Attributes:
#     file:              ./outputs/qck.nc
#     format:            netCDF-3 64bit offset file
#     Conventions:       CF-1.4, SGRID-0.3
#     type:              ROMS/TOMS quicksave file
#     title:             NWS W4DVAR ROMS
#     var_info:          varinfo.dat
#     state_vector:      zeta, ubar, vbar, u, v, temp, salt, sustr, svstr, shfl...
#     rst_file:          ./outputs/rst.nc
#     avg_file:          ./outputs/avg_outer0.nc
#     sta_file:          ./outputs/sta.nc
#     grd_file:          grid.nc
#     ini_file:          ini.nc
#     itl_file:          itl.nc
#     nrm_file:          nrm_i.nc
#     tlf_file:          ./outputs/tlf.nc
#     obs_file:          obs.nc
#     tide_file:         tide.nc
#     frc_file_01:       forcing.nc
#     clm_file_01:       bry.nc
#     fwd_file:          fwd.nc
#     script_file:       ocean.in
#     apar_file:         s4dvar.in
#     spos_file:         stations.in
#     NLM_TADV:          \nADVECTION:   HORIZONTAL   VERTICAL     \ntemp:      ...
#     ADM_TADV:          \nADVECTION:   HORIZONTAL   VERTICAL     \ntemp:      ...
#     NLM_LBC:           \nEDGE:  WEST   SOUTH  EAST   NORTH  \nzeta:  Cha    C...
#     ADM_LBC:           \nEDGE:  WEST   SOUTH  EAST   NORTH  \nzeta:  Cha    C...
#     svn_url:           https://www.myroms.org/svn/src/trunk
#     svn_rev:           1037
#     code_dir:          /group/pawsey0219/ijanekovic/GIT/testing/trunk
#     header_dir:        /group/pawsey0219/ijanekovic/NWS_ASSIM
#     header_file:       nws_w4dvar.h
#     os:                Linux
#     cpu:               x86_64
#     compiler_system:   ftn
#     compiler_command:  /opt/cray/pe/craype/2.5.13/bin/ftn
#     compiler_flags:    -fp-model precise -heap-arrays -ip -O3
#     tiling:            024x010
#     history:           Wed Oct 14 13:09:14 2020: ncks -7 --ppc default=.5 -O ...
#     ana_file:          ROMS/Functionals/ana_btflux.h
#     CPP_options:       NWS_W4DVAR, ADD_FSOBC, ADD_M2OBC, ADJOINT, ADJUST_BOUN...
#     NCO:               netCDF Operators version 4.7.6 (Homepage = http://nco....

# %%
xlims = (110,116.2)
ylims = (-20,-14)

xlims = (112,118.2)
ylims = (-19,-13)

mytime = '2017-05-06 00:00:00'
# mytime = '2017-04-02 00:00:00'

# %%
sst = ds['temp_sur'].sel(ocean_time=mytime, method='nearest').compute()
sst4d = ds4d['temp_sur'].sel(ocean_time=mytime, method='nearest').compute()

# %%
shf = ds['shflux'].sel(ocean_time=mytime, method='nearest').compute()
shf4d = ds4d['shflux'].sel(ocean_time=mytime, method='nearest').compute()

# %%
zeta = ds['zeta'].sel(ocean_time=mytime, method='nearest').compute()
zeta4d = ds4d['zeta'].sel(ocean_time=mytime, method='nearest').compute()

zeta -= zeta.mean()
zeta4d -= zeta4d.mean()

# %%
clims = (25,30)
zetalims = (-0.25,0.25)
plt.figure(figsize=(10,9))
ax=plt.subplot2grid((4,3),(0,0), colspan=3, rowspan=2)
plt.pcolormesh(sst['lon_rho'],sst['lat_rho'], sst.values, vmin=clims[0],vmax=clims[1], cmap='inferno')
plt.colorbar()
ax.set_aspect('equal')
plt.plot([xlims[0],xlims[1],xlims[1],xlims[0],xlims[0]],
        [ylims[0],ylims[0],ylims[1],ylims[1],ylims[0]],'k--')

ax1=plt.subplot2grid((4,3),(2,0), colspan=1, rowspan=1)
plt.pcolormesh(sst['lon_rho'],sst['lat_rho'], sst.values, vmin=clims[0],vmax=clims[1], cmap='inferno')
ax1.set_xlim(xlims)
ax1.set_ylim(ylims)
ax1.set_aspect('equal')

ax2=plt.subplot2grid((4,3),(2,1), colspan=1, rowspan=1)
plt.pcolormesh(sst['lon_rho'],sst['lat_rho'], sst4d.values, vmin=clims[0],vmax=clims[1], cmap='inferno')
ax2.set_xlim(xlims)
ax2.set_ylim(ylims)
ax2.set_aspect('equal')

ax1=plt.subplot2grid((4,3),(3,0), colspan=1, rowspan=1)
plt.pcolormesh(sst['lon_rho'],sst['lat_rho'], zeta.values, vmin=zetalims[0],vmax=zetalims[1], cmap='RdBu')
ax1.set_xlim(xlims)
ax1.set_ylim(ylims)
ax1.set_aspect('equal')

ax2=plt.subplot2grid((4,3),(3,1), colspan=1, rowspan=1)
plt.pcolormesh(sst['lon_rho'],sst['lat_rho'], zeta4d.values, vmin=zetalims[0],vmax=zetalims[1], cmap='RdBu')
ax2.set_xlim(xlims)
ax2.set_ylim(ylims)
ax2.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Interpolate the ROMS data onto a grid
dx = 0.02
xgrd = np.arange(xlims[0],xlims[1],dx)
ygrd = np.arange(ylims[0],ylims[1],dx)
X,Y = np.meshgrid(xgrd, ygrd)
ny,nx = X.shape

xyin = np.array([ds['lon_rho'].values.ravel(), ds['lat_rho'].values.ravel()]).T
xyout = np.array([X.ravel(), Y.ravel()]).T
Fi = BarycentricInterp(xyin, xyout)

# %%
sst4d_i = Fi(sst4d.values.ravel()).reshape((ny,nx))
sst_i = Fi(sst.values.ravel()).reshape((ny,nx))

zeta4d_i = Fi(zeta4d.values.ravel()).reshape((ny,nx))
zeta_i = Fi(zeta.values.ravel()).reshape((ny,nx))

plt.figure()
# plt.pcolormesh(X,Y, sst_i-sst_i.mean(axis=0))
plt.pcolormesh(X,Y, zeta_i-zeta_i.mean(axis=0))

# plt.pcolormesh(X,Y, sst4d_i-sst4d_i.mean(axis=0))

plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# See here: https://currents.soest.hawaii.edu/ocn_data_analysis/_static/Spectrum.html

def window_sinetaper(M,K=3):
    # Generate the time-domain taper for the FFT
    h_tk = np.zeros((K,M))
    t=np.arange(M,dtype=np.double)
    for k in range(K):
        h_tk[k,:] = np.sqrt(2./(M+1.))*np.sin( (k+1)*np.pi*t / (M+1.) ) 

    return h_tk
 
def power_spectra_old(tsec, u_r, power=2., axis=-1):
    """
    Calculates the power spectral density from a real valued quanity
    
    """
    
    M = tsec.shape[0]
    dt = tsec[1]-tsec[0]
    #dt *= 2*np.pi
    M_2 = int(np.floor(M/2))
    
    #h_tk = window_sinetaper(M,K=K)
   
    # Weight the time-series and perform the fft
    u_r_t = u_r#*h_tk
    S_k = np.fft.fft(u_r_t, axis=axis)
    S = dt*np.abs(S_k)**power 
    #S = np.mean(S_k,axis=-2)
        
    omega = np.fft.fftfreq(int(M),d=dt)
    
    #domega = 2*np.pi/(M*dt)
    #domega = 1/(M*dt)
    
    # Extract the positive and negative frequencies
    omega_ccw = omega[0:M_2]
    #omega_cw = omega[M_2::] # negative frequencies
    S_ccw = S[...,0:M_2]
    #S_cw = S[...,M_2::]
    
    #return omega, S
    return omega_ccw,S_ccw/M

def quadwin(n):
    """
    Quadratic (or "Welch") window
    """
    t = np.arange(n)
    win = 1 - ((t - 0.5 * n) / (0.5 * n)) ** 2
    return win

def power_spectra(h, dt=1, axis=-1):
    """
    First cut at spectral estimation: very crude.
    
    Returns frequencies, power spectrum, and
    power spectral density.
    Only positive frequencies between (and not including)
    zero and the Nyquist are output.
    """
    nt = len(h)
    npositive = nt//2
    winweights = quadwin(nt)
    #winweights = np.ones((nt,))
    pslice = slice(1, npositive)
    freqs = np.fft.fftfreq(nt, d=dt)[pslice]
    ft = np.fft.fft(h, axis=axis)[...,pslice] 
    psraw = np.abs(ft) ** 2
    # Double to account for the energy in the negative frequencies.
    psraw *= 2
    
    # Normalization for Power Spectrum
    psraw /= nt**2
    
    # Convert PS to Power Spectral Density
    psdraw = psraw * dt * nt  # nt * dt is record length
    
    psdraw *= nt / (winweights**2).sum()
    
    return freqs,  psdraw

# %%
dx = 2 # km
k_x, S_4d_zonal = power_spectra( sst4d_i-sst4d_i.mean(axis=0), dt=dx/(2*np.pi), axis=1)
k_x, S_zonal = power_spectra( sst_i-sst_i.mean(axis=0), dt=dx/(2*np.pi), axis=1)

S_roms = np.median(S_zonal,axis=0)
S_roms_4d = np.median(S_4d_zonal,axis=0)

# k_y, S_merid, domega = power_spectra(ygrd, sst_i-sst_i.mean(), axis=0)

# %%
yin = sst_i-sst_i.mean(axis=0)
# k_x, S_4d_zonal = power_spectra(xgrd_dist, yin , axis=1)

np.var(yin,axis=0)[2], np.trapz(S_zonal[2,:], k_x)#, np.sum(S_zonal[10,:]*domega)
# Out:
# (0.09803015622297116, 0.13037568640778205)

# %%
plt.figure()
# plt.loglog(k_x, S_zonal[0,:])
# plt.loglog(k_x, S_zonal[2,:])
plt.loglog(k_x, S_roms,'r')
plt.loglog(k_x, S_roms_4d,'k')
plt.legend(('ROMS','ROMS-4DVAR'))
plt.xlabel('Zonal wavenumber [cpkm]')
plt.ylabel('PSD [$^\circ$C$^2$ (cpkm)$^{-1}$]')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Plot SSH
dx = 2 # km
k_x, Sz_4d_zonal = power_spectra( zeta4d_i-zeta4d_i.mean(axis=0), dt=dx/(2*np.pi), axis=1)
k_x, Sz_zonal = power_spectra( zeta_i-zeta_i.mean(axis=0), dt=dx/(2*np.pi), axis=1)

Sz_roms = np.median(Sz_zonal,axis=0)
Sz_roms_4d = np.median(Sz_4d_zonal,axis=0)


plt.figure()
# plt.loglog(k_x, S_zonal[0,:])
# plt.loglog(k_x, S_zonal[2,:])
plt.loglog(k_x, Sz_roms,'r')
plt.loglog(k_x, Sz_roms_4d,'k')
plt.legend(('ROMS','ROMS-4DVAR'))
plt.xlabel('Zonal wavenumber [cpkm]')
plt.ylabel('PSD [m$^2$ (cpkm)$^{-1}$]')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
2*np.pi/0.05
# Out:
# 125.66370614359172

# %%
# Interpolate the spectra between 300 and 50 km wavenumber
def fit_slope(highscale, lowscale, k, S):
    k_high = np.log10(2*np.pi/highscale)
    k_low = np.log10(2*np.pi/lowscale)
    k_i = np.linspace(k_high, k_low,100)

    Fi = interp1d(np.log10(k), np.log10(S))
    
    S_roms_i_log = Fi(k_i)
    p1 = np.polyfit(k_i, S_roms_i_log, 1)
    
    return p1, 10**k_i, 10**(p1[1]+p1[0]*k_i)

proms, ki, S_roms_fit = fit_slope(300, 50, k_x, S_roms)
proms4d, ki, S_roms4d_fit = fit_slope(300, 50, k_x, S_roms_4d)

plt.figure()
# plt.loglog(k_x, S_zonal[0,:])
# plt.loglog(k_x, S_zonal[2,:])
plt.loglog(k_x, S_roms,'r')
plt.loglog(k_x, S_roms_4d,'k')

# plt.loglog(10**k_i, 10**S_roms_i_log, 'r.')
plt.loglog(ki, S_roms_fit,'r--')
plt.loglog(ki, S_roms4d_fit,'k--')

plt.text(0.09, 1e-1, 'k$\sim$%3.1f'%proms[0],color='r')
plt.text(0.09, 1e-2, 'k$\sim$%3.1f'%proms4d[0],color='k')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.09, 0.01, 'k$\\sim$-1.3')

# %%
pzroms, ki, Sz_roms_fit = fit_slope(400, 30, k_x, Sz_roms)
pzroms4d, ki, Sz_roms4d_fit = fit_slope(400, 30, k_x, Sz_roms_4d)

plt.figure()
# plt.loglog(k_x, S_zonal[0,:])
# plt.loglog(k_x, S_zonal[2,:])
plt.loglog(k_x, Sz_roms,'r')
plt.loglog(k_x, Sz_roms_4d,'k')

# plt.loglog(10**k_i, 10**S_roms_i_log, 'r.')
plt.loglog(ki, Sz_roms_fit,'r--')
plt.loglog(ki, Sz_roms4d_fit,'k--')

plt.text(0.04, 1e-4, 'k$\sim$%3.1f'%pzroms[0],color='r')
plt.text(0.08, 1e-2, 'k$\sim$%3.1f'%pzroms4d[0],color='k')

plt.legend(('ROMS','ROMS-4DVAR'))
plt.xlabel('Zonal wavenumber [cpkm]')
plt.ylabel('PSD [m$^2$ (cpkm)$^{-1}$]')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# -3.6666666666666665

# %%
# dt = 12.
# t = np.arange(0,3600,dt)
# nt = t.shape[0]
# omega = 2*np.pi/900
# y = 1.2*np.sin(omega*t)

# k_x, S = power_spectra( y , dt=dt/(2*np.pi))

# # plt.figure()
# # plt.plot(t,y)
# print(np.var(y),np.trapz(S, k_x))

# plt.figure()
# plt.loglog(k_x,S)

# %%
plt.figure(figsize=(9,9))
ax=plt.subplot2grid((3,3),(0,0), colspan=3, rowspan=2)
plt.pcolormesh(sst['lon_rho'],sst['lat_rho'], sst.values, vmin=25,vmax=31, cmap='inferno')
plt.colorbar()
ax.set_aspect('equal')
plt.plot([xlims[0],xlims[1],xlims[1],xlims[0],xlims[0]],
        [ylims[0],ylims[0],ylims[1],ylims[1],ylims[0]],'k--')

plt.title(mytime)
ax1=plt.subplot2grid((3,3),(2,0), colspan=1, rowspan=1)
plt.pcolormesh(sst['lon_rho'],sst['lat_rho'], sst.values, vmin=25,vmax=31, cmap='inferno')
ax1.set_xlim(xlims)
ax1.set_ylim(ylims)
ax1.set_aspect('equal')
plt.title('ROMS - SST')
# ax1.set_xticklabels([])

ax2=plt.subplot2grid((3,3),(2,1), colspan=1, rowspan=1)
plt.pcolormesh(sst['lon_rho'],sst['lat_rho'], sst4d.values, vmin=25,vmax=31, cmap='inferno')
ax2.set_xlim(xlims)
ax2.set_ylim(ylims)
ax2.set_aspect('equal')
ax2.set_yticklabels([])
plt.title('ROMS 4DVAR- SST')

# ax2.set_xticklabels([])


# ax1=plt.subplot2grid((4,3),(3,0), colspan=1, rowspan=1)
# plt.pcolormesh(sst['lon_rho'],sst['lat_rho'], shf.values, vmin=-500,vmax=500, cmap='RdBu')
# ax1.set_xlim(xlims)
# ax1.set_ylim(ylims)
# ax1.set_aspect('equal')

# ax2=plt.subplot2grid((4,3),(3,1), colspan=1, rowspan=1)
# plt.pcolormesh(sst['lon_rho'],sst['lat_rho'], shf4d.values, vmin=-500,vmax=500, cmap='RdBu')
# ax2.set_xlim(xlims)
# ax2.set_ylim(ylims)
# ax2.set_aspect('equal')
# ax2.set_yticklabels([])

# PSD plot
ax4=plt.subplot2grid((3,3),(2,2), colspan=1, rowspan=1)
plt.loglog(k_x, S_roms,'r')
plt.loglog(k_x, S_roms_4d,'k')

# plt.loglog(10**k_i, 10**S_roms_i_log, 'r.')
plt.loglog(ki, S_roms_fit,'r--')
plt.loglog(ki, S_roms4d_fit,'k--')

plt.text(0.02, 1e-3, 'k$\sim$%3.1f'%proms[0],color='r')
plt.text(0.09, 1e-1, 'k$\sim$%3.1f'%proms4d[0],color='k')

plt.legend(('ROMS','ROMS-4DVAR'),loc=(0.1,0.9))
plt.xlabel('Zonal wavenumber [cpkm]')
plt.ylabel('PSD [$^\circ$C$^2$ (cpkm)$^{-1}$]')
plt.xlim(1e-2,1)
plt.grid(b=True)

plt.tight_layout()

plt.savefig('../FIGURES/ROMS_SST_Wavenumber_Spectra.png',dpi=150)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
2*np.pi/100
# Out:
# 0.06283185307179587
